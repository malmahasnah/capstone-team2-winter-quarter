# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap
from geopy.geocoders import Nominatim
import time
import plotly.express as px

# %%
df = pd.read_csv("Student Depression Dataset.csv")
# Drop rows with missing coordinates
df.dropna(inplace=True)

# %%
# online data
city_coords = {
    "Kalyan": [19.2403, 73.1305],
    "Srinagar": [34.0837, 74.7973],
    "Hyderabad": [17.3871, 78.4917],
    "Vasai-Virar": [19.3919, 72.8397],
    "Ludhiana": [30.9010, 75.8573],
    "Thane": [19.2183, 72.9781],
    "Kolkata": [22.5726, 88.3639],
    "Lucknow": [26.8467, 80.9462],
    "Agra": [27.1767, 78.0081],
    "Jaipur": [26.9124, 75.7873],
    "Patna": [25.5941, 85.1376],
    "Surat": [21.1702, 72.8311],
    "Bhopal": [23.2599, 77.4126],
    "Pune": [18.5204, 73.8567],
    "Visakhapatnam": [17.6868, 83.2185],
    "Ahmedabad": [23.0225, 72.5714],
    "Chennai": [13.0827, 80.2707],
    "Ghaziabad": [28.6692, 77.4538],
    "Meerut": [28.9845, 77.7064],
    "Mumbai": [19.0760, 72.8777],
    "Rajkot": [22.3039, 70.8022],
    "Bangalore": [12.9716, 77.5946],
    "Delhi": [28.7041, 77.1025],
    "Vadodara": [22.3072, 73.1812],
    "Varanasi": [25.3176, 82.9739],
    "Nagpur": [21.1458, 79.0882],
    "Indore": [22.7196, 75.8577],
    "Kanpur": [26.4499, 80.3319],
    "Nashik": [19.9975, 73.7898],
    "Faridabad": [28.4089, 77.3178]
}

# %%
# Map city names to coordinates
df['Coordinates'] = df['City'].map(city_coords)

# Group by 'City' and calculate total and depressed counts
grouped = df.groupby('City')['Depression'].agg(
    Total_Count='size',
    Depressed_Count='sum'
).reset_index()

# Calculate depression percentage
grouped['Depression_Percentage'] = (grouped['Depressed_Count'] / grouped['Total_Count']) * 100


# Normalize Depression_Percentage to a 0-1 scale
grouped['Normalized_Depression'] = grouped['Depression_Percentage'] / 100

# Create a folium map centered around India
m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

# Prepare heatmap data
heat_data = [[coord[0], coord[1], weight] for coord, weight in zip(df['Coordinates'], grouped['Normalized_Depression'])]

# Add HeatMap layer
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(m)

# Save the map to an HTML file
m.save("depression_heatmap.html")

# Display the map in a Jupyter Notebook (optional)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdfd44a3ed745870042f32655f85864c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdfd44a3ed745870042f32655f85864c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdfd44a3ed745870042f32655f85864c = L.map(
#                 &quot;map_fdfd44a3ed745870042f32655f85864c&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1952732cd95c333efedef3e7781f56f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1952732cd95c333efedef3e7781f56f3.addTo(map_fdfd44a3ed745870042f32655f85864c);
#
#
#             var heat_map_fd1f2c43b5d482a965a46c34af7fb283 = L.heatLayer(
#                 [[17.6868, 83.2185, 1.0], [12.9716, 77.5946, 0.5347349177330896], [34.0837, 74.7973, 0.6729758149316509], [25.3176, 82.9739, 0.6088657105606258], [26.9124, 75.7873, 1.0], [18.5204, 73.8567, 0.619914346895075], [19.2183, 72.9781, 0.5966101694915255], [13.0827, 80.2707, 0.5], [21.1458, 79.0882, 0.609375], [19.9975, 73.7898, 0.5878524945770065], [21.1458, 79.0882, 1.0], [22.3072, 73.1812, 0.574496644295302], [19.2403, 73.1305, 1.0], [22.3039, 70.8022, 0.5], [19.2403, 73.1305, 0.6699029126213593], [34.0837, 74.7973, 0.6049766718506998], [19.9975, 73.7898, 0.5241312741312741], [23.0225, 72.5714, 0.5949044585987261], [13.0827, 80.2707, 0.541871921182266], [19.2403, 73.1305, 1.0], [22.5726, 88.3639, 0.0], [22.5726, 88.3639, 0.6093896713615023], [23.0225, 72.5714, 0.0], [19.2183, 72.9781, 0.0], [12.9716, 77.5946, 0.554978354978355], [19.076, 72.8777, 0.5823582358235824], [23.0225, 72.5714, 1.0], [26.8467, 80.9462, 0.0], [22.7196, 75.8577, 0.0], [19.2403, 73.1305, 0.5975757575757575], [21.1702, 72.8311, 1.0], [17.6868, 83.2185, 1.0], [26.9124, 75.7873, 0.5522174535050072], [19.2403, 73.1305, 0.5576036866359447], [21.1702, 72.8311, 1.0], [30.901, 75.8573, 0.0], [23.2599, 77.4126, 0.0], [34.0837, 74.7973, 0.5283363802559415], [19.2183, 72.9781, 0.631578947368421], [28.9845, 77.7064, 0.5588842975206612], [19.2183, 72.9781, 0.6262254901960784], [27.1767, 78.0081, 0.0], [27.1767, 78.0081, 0.0], [28.6692, 77.4538, 1.0], [13.0827, 80.2707, 0.5561224489795918], [26.8467, 80.9462, 0.5797773654916512], [28.9845, 77.7064, 0.5908691834942933], [17.3871, 78.4917, 1.0], [19.2403, 73.1305, 0.5619596541786743], [22.3039, 70.8022, 0.5307017543859649], [19.2403, 73.1305, 0.5728682170542636], [19.3919, 72.8397, 0.5696594427244582]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 10,
# }
#             );
#
#
#             heat_map_fd1f2c43b5d482a965a46c34af7fb283.addTo(map_fdfd44a3ed745870042f32655f85864c);
#
#
#             tile_layer_1952732cd95c333efedef3e7781f56f3.addTo(map_fdfd44a3ed745870042f32655f85864c);
#
#
#             heat_map_fd1f2c43b5d482a965a46c34af7fb283.addTo(map_fdfd44a3ed745870042f32655f85864c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
grouped
# Out:
#                   City  Total_Count  Depressed_Count  Depression_Percentage  \
# 0                  3.0            1                1             100.000000
# 1                 Agra         1094              585              53.473492
# 2            Ahmedabad          951              640              67.297581
# 3            Bangalore          767              467              60.886571
# 4               Bhavna            2                2             100.000000
# 5               Bhopal          934              579              61.991435
# 6              Chennai          885              528              59.661017
# 7                 City            2                1              50.000000
# 8                Delhi          768              468              60.937500
# 9            Faridabad          461              271              58.785249
# 10              Gaurav            1                1             100.000000
# 11           Ghaziabad          745              428              57.449664
# 12               Harsh            1                1             100.000000
# 13              Harsha            2                1              50.000000
# 14           Hyderabad         1339              897              66.990291
# 15              Indore          643              389              60.497667
# 16              Jaipur         1036              543              52.413127
# 17              Kalyan         1570              934              59.490446
# 18              Kanpur          609              330              54.187192
# 19           Khaziabad            1                1             100.000000
# 20              Kibara            1                0               0.000000
# 21             Kolkata         1065              649              60.938967
# 22          Less Delhi            1                0               0.000000
# 23  Less than 5 Kalyan            1                0               0.000000
# 24             Lucknow         1155              641              55.497835
# 25            Ludhiana         1111              647              58.235824
# 26               M.Com            1                1             100.000000
# 27              M.Tech            1                0               0.000000
# 28                  ME            1                0               0.000000
# 29              Meerut          825              493              59.757576
# 30               Mihir            1                1             100.000000
# 31                Mira            1                1             100.000000
# 32              Mumbai          699              386              55.221745
# 33              Nagpur          651              363              55.760369
# 34              Nalini            1                1             100.000000
# 35              Nalyan            1                0               0.000000
# 36             Nandini            1                0               0.000000
# 37              Nashik          547              289              52.833638
# 38               Patna         1007              636              63.157895
# 39                Pune          968              541              55.888430
# 40              Rajkot          816              511              62.622549
# 41               Rashi            1                0               0.000000
# 42             Reyansh            1                0               0.000000
# 43              Saanvi            2                2             100.000000
# 44            Srinagar         1372              763              55.612245
# 45               Surat         1078              625              57.977737
# 46               Thane         1139              673              59.086918
# 47              Vaanya            1                1             100.000000
# 48            Vadodara          694              390              56.195965
# 49            Varanasi          684              363              53.070175
# 50         Vasai-Virar         1290              739              57.286822
# 51       Visakhapatnam          969              552              56.965944
#
#     Normalized_Depression
# 0                1.000000
# 1                0.534735
# 2                0.672976
# 3                0.608866
# 4                1.000000
# 5                0.619914
# 6                0.596610
# 7                0.500000
# 8                0.609375
# 9                0.587852
# 10               1.000000
# 11               0.574497
# 12               1.000000
# 13               0.500000
# 14               0.669903
# 15               0.604977
# 16               0.524131
# 17               0.594904
# 18               0.541872
# 19               1.000000
# 20               0.000000
# 21               0.609390
# 22               0.000000
# 23               0.000000
# 24               0.554978
# 25               0.582358
# 26               1.000000
# 27               0.000000
# 28               0.000000
# 29               0.597576
# 30               1.000000
# 31               1.000000
# 32               0.552217
# 33               0.557604
# 34               1.000000
# 35               0.000000
# 36               0.000000
# 37               0.528336
# 38               0.631579
# 39               0.558884
# 40               0.626225
# 41               0.000000
# 42               0.000000
# 43               1.000000
# 44               0.556122
# 45               0.579777
# 46               0.590869
# 47               1.000000
# 48               0.561960
# 49               0.530702
# 50               0.572868
# 51               0.569659

# %% [markdown]
# - The cities selected by our LASSO: [Bhavna, Kibara, ME, Mira, Nalyan, Nandini, Saanvi, Vaanya]
# - The cities that are selected by LASSO are all cities with only one entry of them, meaning they will not generalize
# - The brightest city/areas are Kalyan, Meerut + Ghaziabad

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# 1                0.0  5.90                 5.0               0.0
# 2                0.0  7.03                 5.0               0.0
# 3                0.0  5.59                 2.0               0.0
# 4                0.0  8.13                 3.0               0.0
# ...              ...   ...                 ...               ...
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 0              5-6 hours        Healthy   B.Pharm
# 1              5-6 hours       Moderate       BSc
# 2      Less than 5 hours        Healthy        BA
# 3              7-8 hours       Moderate       BCA
# 4              5-6 hours       Moderate    M.Tech
# ...                  ...            ...       ...
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# 27898          5-6 hours      Unhealthy        MD
# 27899  Less than 5 hours        Healthy  Class 12
# 27900  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                       Yes               3.0
# 1                                        No               3.0
# 2                                        No               9.0
# 3                                       Yes               4.0
# 4                                       Yes               1.0
# ...                                     ...               ...
# 27896                                   Yes               7.0
# 27897                                    No               0.0
# 27898                                    No              12.0
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#        Financial Stress Family History of Mental Illness  Depression  \
# 0                   1.0                               No           1
# 1                   2.0                              Yes           0
# 2                   1.0                              Yes           0
# 3                   5.0                              Yes           1
# 4                   1.0                               No           0
# ...                 ...                              ...         ...
# 27896               1.0                              Yes           0
# 27897               3.0                              Yes           0
# 27898               2.0                               No           0
# 27899               5.0                               No           1
# 27900               3.0                              Yes           1
#
#               Coordinates
# 0      [17.6868, 83.2185]
# 1      [12.9716, 77.5946]
# 2      [34.0837, 74.7973]
# 3      [25.3176, 82.9739]
# 4      [26.9124, 75.7873]
# ...                   ...
# 27896  [21.1702, 72.8311]
# 27897   [30.901, 75.8573]
# 27898  [28.4089, 77.3178]
# 27899   [30.901, 75.8573]
# 27900  [25.5941, 85.1376]
#
# [27898 rows x 19 columns]

# %%
df["Profession"].value_counts()
# Out:
# Student                   27867
# Architect                     8
# Teacher                       6
# Digital Marketer              3
# Content Writer                2
# Chef                          2
# Doctor                        2
# Pharmacist                    2
# Civil Engineer                1
# UX/UI Designer                1
# Educational Consultant        1
# Manager                       1
# Lawyer                        1
# Entrepreneur                  1
# Name: Profession, dtype: int64

# %%
df[df["Profession"] != "Student"]
# Out:
#            id  Gender   Age           City              Profession  \
# 113       609    Male  21.0      Ahmedabad          Civil Engineer
# 422      2105  Female  31.0       Vadodara               Architect
# 1845     9483  Female  32.0         Kalyan          UX/UI Designer
# 2249    11470  Female  28.0      Ahmedabad        Digital Marketer
# 2440    12425    Male  25.0         Kalyan          Content Writer
# 3220    16196    Male  33.0         Jaipur               Architect
# 3388    16959  Female  24.0         Mumbai               Architect
# 3639    18291    Male  32.0           Agra  Educational Consultant
# 3841    19226    Male  31.0         Rajkot                 Teacher
# 5016    25193    Male  24.0         Kalyan                 Teacher
# 8537    43035    Male  23.0          Patna                 Manager
# 12124   61219  Female  23.0         Kalyan                    Chef
# 12350   62410  Female  34.0      Ghaziabad          Content Writer
# 14352   72541  Female  28.0      Hyderabad               Architect
# 15472   78083    Male  32.0         Meerut                  Doctor
# 16108   81442    Male  23.0         Kanpur                  Lawyer
# 17550   88879  Female  29.0           Agra                    Chef
# 17585   89052  Female  29.0         Meerut                  Doctor
# 18213   92226    Male  26.0         Bhopal               Architect
# 20568  104123    Male  28.0       Ludhiana        Digital Marketer
# 20801  105237  Female  21.0        Chennai            Entrepreneur
# 20872  105595    Male  28.0         Jaipur                 Teacher
# 22178  111939    Male  24.0      Bangalore               Architect
# 24121  121474    Male  27.0         Kalyan                 Teacher
# 24482  123259    Male  23.0         Kanpur                 Teacher
# 25219  127070    Male  32.0         Meerut              Pharmacist
# 25335  127637  Female  25.0          Delhi               Architect
# 25689  129499  Female  21.0         Kalyan        Digital Marketer
# 26289  132550    Male  25.0  Visakhapatnam                 Teacher
# 27109  136642    Male  29.0       Ludhiana              Pharmacist
# 27873  140522  Female  22.0    Vasai-Virar               Architect
#
#        Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 113                  5.0            0.0  7.83                 1.0
# 422                  5.0            0.0  6.95                 3.0
# 1845                 3.0            0.0  9.60                 2.0
# 2249                 5.0            0.0  9.72                 3.0
# 2440                 5.0            0.0  8.50                 2.0
# 3220                 2.0            0.0  7.13                 4.0
# 3388                 3.0            0.0  8.89                 5.0
# 3639                 3.0            0.0  5.74                 4.0
# 3841                 3.0            0.0  7.48                 5.0
# 5016                 4.0            0.0  9.66                 5.0
# 8537                 3.0            0.0  8.62                 2.0
# 12124                3.0            0.0  9.91                 4.0
# 12350                5.0            0.0  6.83                 4.0
# 14352                3.0            0.0  6.99                 3.0
# 15472                5.0            0.0  9.70                 3.0
# 16108                4.0            0.0  6.88                 1.0
# 17550                2.0            0.0  6.86                 3.0
# 17585                3.0            0.0  6.35                 3.0
# 18213                4.0            0.0  7.28                 3.0
# 20568                1.0            0.0  9.41                 5.0
# 20801                3.0            0.0  8.17                 5.0
# 20872                3.0            0.0  5.82                 4.0
# 22178                5.0            0.0  7.09                 4.0
# 24121                3.0            0.0  5.89                 3.0
# 24482                3.0            0.0  5.59                 1.0
# 25219                4.0            0.0  8.54                 1.0
# 25335                5.0            0.0  8.98                 3.0
# 25689                5.0            0.0  6.91                 4.0
# 26289                5.0            0.0  7.25                 1.0
# 27109                4.0            0.0  5.77                 4.0
# 27873                3.0            0.0  9.13                 4.0
#
#        Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 113                 0.0          5-6 hours        Healthy      MSc
# 422                 0.0  Less than 5 hours       Moderate      BSc
# 1845                0.0          7-8 hours       Moderate      PhD
# 2249                0.0  More than 8 hours        Healthy       MA
# 2440                0.0          5-6 hours       Moderate     B.Ed
# 3220                0.0  More than 8 hours       Moderate      MSc
# 3388                0.0  More than 8 hours      Unhealthy      MSc
# 3639                0.0          7-8 hours        Healthy     B.Ed
# 3841                0.0          5-6 hours      Unhealthy       MD
# 5016                0.0          7-8 hours       Moderate       BE
# 8537                0.0  More than 8 hours        Healthy      BHM
# 12124               0.0          7-8 hours        Healthy      BHM
# 12350               0.0          7-8 hours       Moderate       MA
# 14352               0.0          5-6 hours       Moderate      BSc
# 15472               0.0  Less than 5 hours        Healthy  M.Pharm
# 16108               0.0  More than 8 hours      Unhealthy      LLM
# 17550               0.0          7-8 hours       Moderate      BHM
# 17585               0.0  Less than 5 hours        Healthy       MD
# 18213               0.0  More than 8 hours        Healthy      BSc
# 20568               0.0          5-6 hours        Healthy       BA
# 20801               0.0  Less than 5 hours       Moderate      MCA
# 20872               0.0          5-6 hours       Moderate       MD
# 22178               0.0  Less than 5 hours      Unhealthy      BBA
# 24121               0.0  Less than 5 hours      Unhealthy      MSc
# 24482               0.0  More than 8 hours        Healthy      BCA
# 25219               0.0          7-8 hours      Unhealthy     MBBS
# 25335               0.0  More than 8 hours        Healthy   B.Arch
# 25689               0.0  Less than 5 hours       Moderate    M.Com
# 26289               0.0          7-8 hours      Unhealthy     B.Ed
# 27109               0.0  More than 8 hours        Healthy  B.Pharm
# 27873               0.0          7-8 hours      Unhealthy      MCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 113                                     Yes              11.0
# 422                                      No               8.0
# 1845                                    Yes               5.0
# 2249                                    Yes              10.0
# 2440                                    Yes               0.0
# 3220                                     No               2.0
# 3388                                    Yes               3.0
# 3639                                    Yes               3.0
# 3841                                    Yes              12.0
# 5016                                    Yes              12.0
# 8537                                     No               9.0
# 12124                                   Yes              10.0
# 12350                                   Yes               5.0
# 14352                                   Yes              10.0
# 15472                                   Yes               3.0
# 16108                                   Yes               2.0
# 17550                                   Yes              12.0
# 17585                                    No              12.0
# 18213                                    No              12.0
# 20568                                   Yes               5.0
# 20801                                   Yes               4.0
# 20872                                   Yes               5.0
# 22178                                   Yes               1.0
# 24121                                   Yes               2.0
# 24482                                   Yes              11.0
# 25219                                   Yes               2.0
# 25335                                   Yes               5.0
# 25689                                    No              10.0
# 26289                                   Yes               1.0
# 27109                                   Yes               4.0
# 27873                                   Yes               4.0
#
#        Financial Stress Family History of Mental Illness  Depression  \
# 113                 3.0                              Yes           1
# 422                 1.0                              Yes           1
# 1845                3.0                               No           1
# 2249                5.0                              Yes           1
# 2440                2.0                              Yes           1
# 3220                5.0                              Yes           1
# 3388                5.0                              Yes           1
# 3639                5.0                              Yes           1
# 3841                2.0                              Yes           1
# 5016                3.0                               No           1
# 8537                5.0                               No           1
# 12124               3.0                               No           1
# 12350               5.0                               No           1
# 14352               5.0                              Yes           1
# 15472               4.0                               No           1
# 16108               4.0                               No           1
# 17550               4.0                              Yes           1
# 17585               1.0                               No           1
# 18213               4.0                              Yes           0
# 20568               3.0                              Yes           0
# 20801               3.0                               No           1
# 20872               1.0                               No           0
# 22178               3.0                              Yes           1
# 24121               5.0                               No           1
# 24482               4.0                              Yes           1
# 25219               5.0                              Yes           1
# 25335               5.0                               No           1
# 25689               5.0                               No           1
# 26289               1.0                              Yes           1
# 27109               2.0                               No           1
# 27873               1.0                              Yes           1
#
#               Coordinates
# 113    [23.0225, 72.5714]
# 422    [22.3072, 73.1812]
# 1845   [19.2403, 73.1305]
# 2249   [23.0225, 72.5714]
# 2440   [19.2403, 73.1305]
# 3220   [26.9124, 75.7873]
# 3388    [19.076, 72.8777]
# 3639   [27.1767, 78.0081]
# 3841   [22.3039, 70.8022]
# 5016   [19.2403, 73.1305]
# 8537   [25.5941, 85.1376]
# 12124  [19.2403, 73.1305]
# 12350  [28.6692, 77.4538]
# 14352  [17.3871, 78.4917]
# 15472  [28.9845, 77.7064]
# 16108  [26.4499, 80.3319]
# 17550  [27.1767, 78.0081]
# 17585  [28.9845, 77.7064]
# 18213  [23.2599, 77.4126]
# 20568   [30.901, 75.8573]
# 20801  [13.0827, 80.2707]
# 20872  [26.9124, 75.7873]
# 22178  [12.9716, 77.5946]
# 24121  [19.2403, 73.1305]
# 24482  [26.4499, 80.3319]
# 25219  [28.9845, 77.7064]
# 25335  [28.7041, 77.1025]
# 25689  [19.2403, 73.1305]
# 26289  [17.6868, 83.2185]
# 27109   [30.901, 75.8573]
# 27873  [19.3919, 72.8397]
